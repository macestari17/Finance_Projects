# %% [markdown]
# # Import Data

# %%
import yfinance as yf
import pandas as pd

tickers = ['PG', 'BEI.DE']
start_date = '2007-01-01'

sec_data = pd.DataFrame()

for t in tickers:      
    sec_data[t] = yf.download(t, start=start_date)['Adj Close']

# %%
sec_data

# %%
sec_data.info()

# %% [markdown]
# # Calculate Log Return

# %%
import numpy as np

sec_returns = np.log(sec_data / sec_data.shift(1))

# %%
sec_returns

# %% [markdown]
# # Calculate Portfolio Variance

# %%
weights = np.array([0.5, 0.5])

# %% [markdown]
# <img src="data:image/png;base64,..." alt="Embedded Image" />

# %%
pfolio_var = np.dot(weights.T, np.dot(sec_returns.cov() * 250, weights))
pfolio_var

# %%
print (str(round(pfolio_var, 5) * 100) + '%')

# %% [markdown]
# # Calculate Portfolio Standard Deviation

# %%
pfolio_std = np.dot(weights.T, np.dot(sec_returns.cov() * 250, weights)) ** 0.5
pfolio_std

# %%
print (str(round(pfolio_std, 5) * 100) + '%')
